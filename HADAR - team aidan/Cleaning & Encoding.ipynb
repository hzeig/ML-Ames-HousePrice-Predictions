# %% [markdown]
#    # House Price Data
#
# ## Steps:
#  - EDA
#  - Cleaning
#  - Encoding
#  - Modeling
#
# Here, handle missing (some Iterative Imputer) and then encoding ordinals and using OneHot for nominals.
#
# **Q:** would it be possible to use encode/OneHot first, and then IterativeImputer for all missing values?
# - difficulty encoding missing values
# - might need to impute and then "unimpute" for IterativeImputer

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy.stats

# %% [markdown]
# #### Load data

# %%
housePrice = pd.read_csv('Ames_HousePrice.csv', low_memory=False)

# %%
housePrice = housePrice.drop(columns=['Unnamed: 0','PID'])

# %% [markdown]
# #### Examine data

# %%
housePrice.shape
# Out:
# (2580, 80)

# %%
housePrice.head()
# Out:
#    GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  LotArea Street  \
# 0        856     126000          30       RL          NaN     7890   Pave
# 1       1049     139500         120       RL         42.0     4235   Pave
# 2       1001     124900          30  C (all)         60.0     6060   Pave
# 3       1039     114000          70       RL         80.0     8146   Pave
# 4       1665     227000          60       RL         70.0     8400   Pave
#
#   Alley LotShape LandContour  ... ScreenPorch PoolArea PoolQC Fence  \
# 0   NaN      Reg         Lvl  ...         166        0    NaN   NaN
# 1   NaN      Reg         Lvl  ...           0        0    NaN   NaN
# 2   NaN      Reg         Lvl  ...           0        0    NaN   NaN
# 3   NaN      Reg         Lvl  ...         111        0    NaN   NaN
# 4   NaN      Reg         Lvl  ...           0        0    NaN   NaN
#
#   MiscFeature MiscVal MoSold YrSold  SaleType  SaleCondition
# 0         NaN       0      3   2010       WD          Normal
# 1         NaN       0      2   2009       WD          Normal
# 2         NaN       0     11   2007       WD          Normal
# 3         NaN       0      5   2009       WD          Normal
# 4         NaN       0     11   2009       WD          Normal
#
# [5 rows x 80 columns]

# %%
housePrice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   GrLivArea      2580 non-null   int64
#  1   SalePrice      2580 non-null   int64
#  2   MSSubClass     2580 non-null   int64
#  3   MSZoning       2580 non-null   object
#  4   LotFrontage    2118 non-null   float64
#  5   LotArea        2580 non-null   int64
#  6   Street         2580 non-null   object
#  7   Alley          168 non-null    object
#  8   LotShape       2580 non-null   object
#  9   LandContour    2580 non-null   object
#  10  Utilities      2580 non-null   object
#  11  LotConfig      2580 non-null   object
#  12  LandSlope      2580 non-null   object
#  13  Neighborhood   2580 non-null   object
#  14  Condition1     2580 non-null   object
#  15  Condition2     2580 non-null   object
#  16  BldgType       2580 non-null   object
#  17  HouseStyle     2580 non-null   object
#  18  OverallQual    2580 non-null   int64
#  19  OverallCond    2580 non-null   int64
#  20  YearBuilt      2580 non-null   int64
#  21  YearRemodAdd   2580 non-null   int64
#  22  RoofStyle      2580 non-null   object
#  23  RoofMatl       2580 non-null   object
#  24  Exterior1st    2580 non-null   object
#  25  Exterior2nd    2580 non-null   object
#  26  MasVnrType     2566 non-null   object
#  27  MasVnrArea     2566 non-null   float64
#  28  ExterQual      2580 non-null   object
#  29  ExterCond      2580 non-null   object
#  30  Foundation     2580 non-null   object
#  31  BsmtQual       2511 non-null   object
#  32  BsmtCond       2511 non-null   object
#  33  BsmtExposure   2509 non-null   object
#  34  BsmtFinType1   2511 non-null   object
#  35  BsmtFinSF1     2579 non-null   float64
#  36  BsmtFinType2   2510 non-null   object
#  37  BsmtFinSF2     2579 non-null   float64
#  38  BsmtUnfSF      2579 non-null   float64
#  39  TotalBsmtSF    2579 non-null   float64
#  40  Heating        2580 non-null   object
#  41  HeatingQC      2580 non-null   object
#  42  CentralAir     2580 non-null   object
#  43  Electrical     2579 non-null   object
#  44  1stFlrSF       2580 non-null   int64
#  45  2ndFlrSF       2580 non-null   int64
#  46  LowQualFinSF   2580 non-null   int64
#  47  BsmtFullBath   2578 non-null   float64
#  48  BsmtHalfBath   2578 non-null   float64
#  49  FullBath       2580 non-null   int64
#  50  HalfBath       2580 non-null   int64
#  51  BedroomAbvGr   2580 non-null   int64
#  52  KitchenAbvGr   2580 non-null   int64
#  53  KitchenQual    2580 non-null   object
#  54  TotRmsAbvGrd   2580 non-null   int64
#  55  Functional     2580 non-null   object
#  56  Fireplaces     2580 non-null   int64
#  57  FireplaceQu    1339 non-null   object
#  58  GarageType     2453 non-null   object
#  59  GarageYrBlt    2451 non-null   float64
#  60  GarageFinish   2451 non-null   object
#  61  GarageCars     2579 non-null   float64
#  62  GarageArea     2579 non-null   float64
#  63  GarageQual     2451 non-null   object
#  64  GarageCond     2451 non-null   object
#  65  PavedDrive     2580 non-null   object
#  66  WoodDeckSF     2580 non-null   int64
#  67  OpenPorchSF    2580 non-null   int64
#  68  EnclosedPorch  2580 non-null   int64
#  69  3SsnPorch      2580 non-null   int64
#  70  ScreenPorch    2580 non-null   int64
#  71  PoolArea       2580 non-null   int64
#  72  PoolQC         9 non-null      object
#  73  Fence          525 non-null    object
#  74  MiscFeature    97 non-null     object
#  75  MiscVal        2580 non-null   int64
#  76  MoSold         2580 non-null   int64
#  77  YrSold         2580 non-null   int64
#  78  SaleType       2580 non-null   object
#  79  SaleCondition  2580 non-null   object
# dtypes: float64(11), int64(26), object(43)
# memory usage: 1.6+ MB

# %% [markdown]
# **Dictionary function to reference feature description**

# %%
with open('housePrice_features') as hp_feat:
    hp_dict = {}
    for line in hp_feat.readlines():
        feature, description = [*line.split(':')]
        hp_dict[feature] = description

# %%
hp_dict['LotFrontage']
# Out:
# ' Linear feet of street connected to property\n'

# %%
# copy of raw data
housePrice_raw = housePrice.copy()

# %% [markdown]
# # Exploratory Data Analysis and Visualization

# %% [markdown]
# ### Plotting and examining all features (categorical and numerical)

# %% [markdown]
# **Plotting function to examine data visually**

# %%
def feature_plot(df,col):
    sns.set_style('darkgrid')
    plt.figure(figsize = (32, 12))
    
    plt.subplot(1, 2, 1)
    
    order = df.groupby(by=[col])['SalePrice'].mean().sort_values().index
    
    if df[col].dtype == 'int64' or df[col].dtype == 'float64':
        sns.distplot(df[col])
        plt.ylabel("Density", fontsize=30)
        plt.title("Density Plot of "+str(col),fontsize=30)
        plt.xticks(fontsize=30)
        
    else: #categorical variable 
        sns.countplot(x=col, data=df, order=order)
        plt.ylabel("Count", fontsize=30)
        
    plt.xlabel(col,fontsize=30)
    plt.xticks(rotation=90,fontsize=30)
    plt.yticks(fontsize=30)
    
    
    plt.subplot(1, 2, 2)
    
    if df[col].dtype == 'int64' or df[col].dtype == 'float64':
        sns.regplot(x=col, y="SalePrice", data=df, scatter_kws={'alpha':0.3})
        plt.title("Sale Price vs "+str(col),fontsize=30)
    else:#categorical variable 
        sns.boxplot(x=col, y="SalePrice", data=df, order=order)
        
    plt.xlabel(col, fontsize=30)
    plt.ylabel("Sale Price", fontsize=30)
    plt.xticks(rotation=90,fontsize=30)
    plt.yticks(fontsize=30)
    plt.subplots_adjust(wspace=0.3)
    plt.show()

# %%
for feature in housePrice:
    pass
#     if feature == 'SalePrice':
#         continue
#     feature_plot(housePrice, feature)

# %% [markdown]
# # Imputing Missing Values

# %%
# function for viewing columns with missing values
def nas(df):
    return df.loc[:, df.isna().sum() > 0 ].isna().sum().sort_values(ascending = False)

# %%
# investigate / impute column NaNs one by one
nas(housePrice)
# Out:
# PoolQC          2571
# MiscFeature     2483
# Alley           2412
# Fence           2055
# FireplaceQu     1241
# LotFrontage      462
# GarageCond       129
# GarageQual       129
# GarageFinish     129
# GarageYrBlt      129
# GarageType       127
# BsmtExposure      71
# BsmtFinType2      70
# BsmtFinType1      69
# BsmtQual          69
# BsmtCond          69
# MasVnrArea        14
# MasVnrType        14
# BsmtHalfBath       2
# BsmtFullBath       2
# TotalBsmtSF        1
# BsmtUnfSF          1
# GarageCars         1
# GarageArea         1
# BsmtFinSF2         1
# BsmtFinSF1         1
# Electrical         1
# dtype: int64

# %%
hp_dict['PoolQC']             
housePrice.PoolQC.unique()
housePrice.PoolQC = housePrice.PoolQC.fillna('none')
housePrice.groupby('PoolQC')['SalePrice'].agg(['mean', 'std', 'count'])
# Out:
#                  mean            std  count
# PoolQC
# Ex      465000.000000  212132.034356      2
# Fa      215500.000000   48790.367902      2
# Gd      215500.000000   62932.503526      2
# TA      170500.000000   51529.117982      3
# none    177786.980941   74571.704907   2571

# %%
hp_dict['MiscFeature']                                                           # drop
housePrice.groupby('MiscFeature')['SalePrice'].agg(['mean', 'std', 'count'])
housePrice = housePrice.drop('MiscFeature', axis = 1)

# %%
hp_dict['Alley']
# housePrice.Alley.unique()
housePrice.Alley.value_counts()
housePrice.Alley = housePrice.Alley.fillna('none')
housePrice.groupby('Alley')['SalePrice'].agg(['count','mean','std'])
# Out:
#        count           mean           std
# Alley
# Grvl     105  126345.990476  36101.160174
# Pave      63  178559.698413  45650.146340
# none    2412  180297.776949  76096.323125

# %%
hp_dict['Fence']  
# Good Privacy - GdPr
# Good Wood - GdWo
# Minimum Privacy - MnPr
# Minimum Wood - MnWw
housePrice.Fence = housePrice.Fence.fillna('none')
housePrice.groupby('Fence')['SalePrice'].agg(['count','mean','std'])
# Out:
#        count           mean           std
# Fence
# GdPrv    111  176726.576577  62331.695505
# GdWo     103  144750.223301  47246.448542
# MnPrv    301  146485.810631  44748.238487
# MnWw      10  131965.000000  22333.856337
# none    2055  184650.134307  78736.302160

# %%
hp_dict['FireplaceQu']
housePrice.FireplaceQu = housePrice.FireplaceQu.fillna('none')
housePrice.groupby('FireplaceQu')['SalePrice'].agg(['count','mean','std'])
# Out:
#              count           mean            std
# FireplaceQu
# Ex              35  340444.542857  112432.168836
# Fa              70  168482.142857   36079.397184
# Gd             619  223019.756058   91182.521787
# Po              43  142528.674419   34116.467478
# TA             572  204473.805944   63380.868389
# none          1241  140650.717164   41618.136667

# %%
hp_dict['LotFrontage']                                 # impute using LotArea
housePrice.loc[housePrice.LotFrontage == 31]
housePrice.groupby('LotFrontage')['SalePrice'].agg(['count','mean','std'])
housePrice = housePrice.drop(columns='LotFrontage')

# %%
nas(housePrice)
# Out:
# GarageCond      129
# GarageQual      129
# GarageFinish    129
# GarageYrBlt     129
# GarageType      127
# BsmtExposure     71
# BsmtFinType2     70
# BsmtQual         69
# BsmtCond         69
# BsmtFinType1     69
# MasVnrType       14
# MasVnrArea       14
# BsmtFullBath      2
# BsmtHalfBath      2
# Electrical        1
# BsmtUnfSF         1
# BsmtFinSF2        1
# GarageCars        1
# GarageArea        1
# BsmtFinSF1        1
# TotalBsmtSF       1
# dtype: int64

# %%
hp_dict['GarageCond']                                                       
housePrice.GarageCond = housePrice.GarageCond.fillna('none')
housePrice.groupby('GarageCond')['SalePrice'].agg(['count','mean','std'])
# Out:
#             count           mean           std
# GarageCond
# Ex              3  125000.000000   3905.124838
# Fa             67  108543.791045  37994.751260
# Gd             14  188278.571429  72267.145196
# Po             11  106618.181818  27559.238675
# TA           2356  184277.848048  74495.805841
# none          129  106814.604651  33428.251290

# %%
hp_dict['GarageQual']                                             # should we try to compile garage? (is that clusters?)
housePrice.GarageQual = housePrice.GarageQual.fillna('none')              # compare relationship between rankings 
housePrice.groupby('GarageQual')['SalePrice'].agg(['count','mean','std'])           # across garage classifications
# Out:
#             count           mean            std
# GarageQual
# Ex              3  241000.000000  202680.166765
# Fa            110  118884.100000   39721.189121
# Gd             22  242833.500000  119708.930561
# Po              4   94350.000000   31556.140448
# TA           2312  184297.039792   73708.905056
# none          129  106814.604651   33428.251290

# %%
hp_dict['GarageFinish']                                             
housePrice.GarageFinish = housePrice.GarageFinish.fillna('none')
housePrice.groupby('GarageFinish')['SalePrice'].agg(['count','mean','std'])
# Out:
#               count           mean           std
# GarageFinish
# Fin             621  231925.247987  89751.688867
# RFn             718  199724.565460  64714.442479
# Unf            1112  142254.430755  44088.459471
# none            129  106814.604651  33428.251290

# %%
hp_dict['GarageYrBlt']                                                         
housePrice.GarageYrBlt = housePrice.GarageYrBlt.fillna(0)
housePrice.groupby('GarageYrBlt')['SalePrice'].agg(['count','mean','std'])
# Out:
#              count           mean            std
# GarageYrBlt
# 0.0            129  106814.604651   33428.251290
# 1895.0           1   89000.000000            NaN
# 1900.0           5  124760.000000   31569.494769
# 1906.0           1  135000.000000            NaN
# 1908.0           1  240000.000000            NaN
# ...            ...            ...            ...
# 2006.0          67  263140.507463   82094.024392
# 2007.0          67  258978.552239   98539.246379
# 2008.0          44  292216.795455   87551.849537
# 2009.0          12  297876.666667  126085.057796
# 2010.0           1  394432.000000            NaN
#
# [101 rows x 3 columns]

# %%
hp_dict['GarageType']                                             
housePrice.GarageType = housePrice.GarageType.fillna('none')
housePrice.groupby('GarageType')['SalePrice'].agg(['count','mean','std'])
# Out:
#             count           mean           std
# GarageType
# 2Types         21  154080.952381  36478.125213
# Attchd       1527  200661.569090  75910.133901
# Basment        27  155150.000000  33391.342153
# BuiltIn       153  233054.464052  80768.842199
# CarPort         9  110716.666667  27859.446333
# Detchd        716  133291.765363  39764.381342
# none          127  106048.622047  33116.655928

# %%
hp_dict['BsmtExposure']                                             
housePrice.BsmtExposure = housePrice.BsmtExposure.fillna('none')
housePrice.groupby('BsmtExposure')['SalePrice'].agg(['count','mean','std'])
# Out:
#               count           mean            std
# BsmtExposure
# Av              344  201482.340116   76537.790904
# Gd              242  262873.061983  113165.344846
# Mn              215  185463.330233   70096.651361
# No             1708  163135.738876   57349.711224
# none             71  112086.816901   42548.995226

# %%
hp_dict['BsmtFinType2']                                             
housePrice.BsmtFinType2 = housePrice.BsmtFinType2.fillna('none')
housePrice.groupby('BsmtFinType2')['SalePrice'].agg(['count','mean','std'])
# Out:
#               count           mean            std
# BsmtFinType2
# ALQ              53  188644.339623   82192.691433
# BLQ              64  161466.140625   57560.260186
# GLQ              32  211278.125000  101942.759031
# LwQ              84  160725.297619   38958.990930
# Rec              97  164338.402062   55684.315058
# Unf            2180  181206.894954   76175.880106
# none             70  111830.914286   44695.624964

# %%
hp_dict['BsmtFinType1']                                             
housePrice.BsmtFinType1 = housePrice.BsmtFinType1.fillna('none')
housePrice.groupby('BsmtFinType1')['SalePrice'].agg(['count','mean','std'])
# Out:
#               count           mean           std
# BsmtFinType1
# ALQ             397  163515.198992  48331.383704
# BLQ             251  150852.749004  44819.815866
# GLQ             753  231889.369190  87608.901286
# LwQ             139  153106.834532  55352.198810
# Rec             265  144782.030189  49548.992468
# Unf             706  162617.998584  63191.379338
# none             69  109335.710145  39810.106680

# %%
hp_dict['BsmtQual']                                            # does it matter if some basements (garages) don't have           
housePrice.BsmtQual = housePrice.BsmtQual.fillna('none')       # certain classifications, and are seen as 'none'
housePrice.groupby('BsmtQual')['SalePrice'].agg(['count','mean','std'])
# Out:
#           count           mean            std
# BsmtQual
# Ex          188  327308.005319  102928.298214
# Fa           78  113467.051282   38699.187921
# Gd         1077  200961.085422   56495.645593
# Po            2   84950.000000    5727.564928
# TA         1166  141389.656947   40290.731298
# none         69  109335.710145   39810.106680

# %%
hp_dict['BsmtCond']                                             
housePrice.BsmtCond = housePrice.BsmtCond.fillna('none')
housePrice.groupby('BsmtCond')['SalePrice'].agg(['count','mean','std'])
# Out:
#           count           mean           std
# BsmtCond
# Ex            3  195000.000000  83216.584885
# Fa           88  122382.875000  44683.700374
# Gd          101  206709.128713  69427.407860
# Po            3   95133.333333  34428.706530
# TA         2316  181058.699914  74981.038735
# none         69  109335.710145  39810.106680

# %%
hp_dict['MasVnrType']
housePrice.MasVnrType = housePrice.MasVnrType.fillna('None')
housePrice.groupby('MasVnrType')['SalePrice'].agg(['count','mean','std'])
# Out:
#             count           mean            std
# MasVnrType
# BrkCmn         20  145450.200000   43092.544242
# BrkFace       804  208615.353234   82393.220408
# None         1573  154854.005086   54413.116186
# Stone         183  246845.519126  101989.391799

# %%
hp_dict['MasVnrArea']
housePrice['MasVnrArea'].fillna(0, inplace=True)

# %%
nas(housePrice)
# Out:
# BsmtFullBath    2
# BsmtHalfBath    2
# BsmtFinSF1      1
# BsmtFinSF2      1
# BsmtUnfSF       1
# TotalBsmtSF     1
# Electrical      1
# GarageCars      1
# GarageArea      1
# dtype: int64

# %%
hp_dict['BsmtHalfBath']
housePrice.BsmtHalfBath = housePrice.BsmtHalfBath.fillna(0)
housePrice.groupby('BsmtHalfBath')['SalePrice'].agg(['count','mean','std'])
# housePrice['BsmtHalfBath'].unique()
# Out:
#               count           mean           std
# BsmtHalfBath
# 0.0            2422  178732.360859  75413.038554
# 1.0             156  167413.782051  68265.360217
# 2.0               2  193750.000000  93691.648507

# %%
hp_dict['BsmtFullBath']
housePrice.BsmtFullBath = housePrice.BsmtHalfBath.fillna(0)
housePrice.groupby('BsmtFullBath')['SalePrice'].agg(['count','mean','std'])
# housePrice['BsmtHalfBath'].unique()
# Out:
#               count           mean           std
# BsmtFullBath
# 0.0            2422  178732.360859  75413.038554
# 1.0             156  167413.782051  68265.360217
# 2.0               2  193750.000000  93691.648507

# %%
hp_dict['BsmtFinSF1']
housePrice.BsmtFinSF1 = housePrice.BsmtFinSF1.fillna(housePrice.BsmtFinSF1.mean())
housePrice.groupby('BsmtFinSF1')['SalePrice'].agg(['count','mean','std'])
# Out:
#             count           mean           std
# BsmtFinSF1
# 0.0           774  157976.060724  63277.881933
# 2.0             1  214000.000000           NaN
# 16.0           12  195682.500000  54076.192396
# 20.0            7  184600.000000  39983.788381
# 24.0           22  202248.136364  25915.452934
# ...           ...            ...           ...
# 2158.0          1  468000.000000           NaN
# 2188.0          1  611657.000000           NaN
# 2257.0          1  615000.000000           NaN
# 2260.0          1  184750.000000           NaN
# 2288.0          1  610000.000000           NaN
#
# [928 rows x 3 columns]

# %%
hp_dict['BsmtFinSF2']
housePrice.BsmtFinSF2 = housePrice.BsmtFinSF2.fillna(housePrice.BsmtFinSF2.mean())
housePrice.groupby('BsmtFinSF2')['SalePrice'].agg(['count','mean','std'])
# Out:
#             count           mean           std
# BsmtFinSF2
# 0.0          2248  179064.810943  76314.061051
# 6.0             1  142500.000000           NaN
# 12.0            1  134000.000000           NaN
# 32.0            1  200000.000000           NaN
# 35.0            1  143250.000000           NaN
# ...           ...            ...           ...
# 1127.0          1  213250.000000           NaN
# 1164.0          1  182000.000000           NaN
# 1393.0          1  584500.000000           NaN
# 1474.0          1  301000.000000           NaN
# 1526.0          1  315000.000000           NaN
#
# [265 rows x 3 columns]

# %%
hp_dict['BsmtUnfSF']
housePrice.BsmtUnfSF = housePrice.BsmtUnfSF.fillna(housePrice.BsmtUnfSF.mean())
housePrice.groupby('BsmtUnfSF')['SalePrice'].agg(['count','mean','std'])
# Out:
#            count       mean           std
# BsmtUnfSF
# 0.0          216  143208.25  56797.218229
# 14.0           1  151000.00           NaN
# 15.0           1  223500.00           NaN
# 17.0           1  245000.00           NaN
# 20.0           1  119900.00           NaN
# ...          ...        ...           ...
# 2042.0         1  253293.00           NaN
# 2046.0         1  372500.00           NaN
# 2062.0         1  270000.00           NaN
# 2153.0         1  380000.00           NaN
# 2336.0         1  386250.00           NaN
#
# [1061 rows x 3 columns]

# %%
hp_dict['TotalBsmtSF']
housePrice.TotalBsmtSF = housePrice.TotalBsmtSF.fillna(housePrice.TotalBsmtSF.mean())
housePrice.groupby('TotalBsmtSF')['SalePrice'].agg(['count','mean','std'])
# Out:
#              count           mean           std
# TotalBsmtSF
# 0.0             68  109781.823529  39931.965258
# 105.0            1  116000.000000           NaN
# 160.0            1  113500.000000           NaN
# 173.0            1   89000.000000           NaN
# 190.0            1   91300.000000           NaN
# ...            ...            ...           ...
# 2846.0           1  500000.000000           NaN
# 3094.0           1  555000.000000           NaN
# 3138.0           1  184750.000000           NaN
# 3200.0           1  430000.000000           NaN
# 3206.0           1  284000.000000           NaN
#
# [990 rows x 3 columns]

# %%
nas(housePrice)
# Out:
# Electrical    1
# GarageCars    1
# GarageArea    1
# dtype: int64

# %%
hp_dict['Electrical']
housePrice.groupby('Electrical')['SalePrice'].agg(['count','mean','std'])
housePrice['Electrical'] = housePrice['Electrical'].fillna(housePrice.Electrical.mode())

# %%
hp_dict['GarageCars']
housePrice.groupby('GarageCars')['SalePrice'].agg(['count','mean','std'])
housePrice['GarageCars'] = housePrice['GarageCars'].fillna(housePrice.GarageCars.median())

# %%
hp_dict['GarageArea']
housePrice.groupby('GarageArea')['SalePrice'].agg(['count','mean','std'])
housePrice['GarageArea'] = housePrice['GarageArea'].fillna(housePrice.GarageArea.median())

# %%
nas(housePrice)
# Out:
# Electrical    1
# dtype: int64

# %%
housePrice.to_csv('HousePrice_Clean.csv', index = False)

# %% [markdown]
# #### Date Columns

# %%
# DATES - dtypes        ### thoughts about combining columns / datetime?

date_ = housePrice.filter(regex='Yr|Mo|Date')
date_.isna().sum()

housePrice['GarageYrBlt'].dtypes                       
housePrice['GarageYrBlt'].astype('int')
# pd.to_datetime(housePrice.GarageYrBlt, format = '%Y')
# Out:
# 0       1939
# 1       1984
# 2       1930
# 3       1940
# 4       2001
#         ...
# 2575    1916
# 2576    1955
# 2577    1949
# 2578    2000
# 2579    1993
# Name: GarageYrBlt, Length: 2580, dtype: int32

# %% [markdown]
# # Encoding ordinals and One Hot Encoding for nominals

# %%
housePrice = pd.read_csv('HousePrice_Clean.csv')

# copy of data without encoding
housePrice_cat = housePrice.copy()

# %%
hp_num = housePrice.select_dtypes(include = [np.number])
hp_cat = housePrice.select_dtypes(exclude = [np.number])
hp_cat_ord = []
hp_cat_nom = []
dropped = []

# %%
# how many numeric and categorical values
print("numeric", hp_num.shape[1])
print("categorical", hp_cat.shape[1])
# Out:
# numeric 36
# categorical 42

# %%
housePrice.groupby('MSZoning')['SalePrice'].agg(['count','mean','std'])
hp_cat_nom.append('MSZoning')
len(hp_cat_nom)
# Out:
# 1

# %%
housePrice.groupby('Street')['SalePrice'].agg(['count','mean','std'])
hp_cat_nom.append('Street')
hp_cat_nom
# Out:
# ['MSZoning', 'Street']

# %%
housePrice.groupby('Alley')['SalePrice'].agg(['count','mean','std'])
hp_cat_nom.append('Alley')
hp_cat_nom
# Out:
# ['MSZoning', 'Street', 'Alley']

# %%
housePrice.groupby('LotShape')['SalePrice'].agg(['count','mean','std'])
hp_cat_nom.append('LotShape')
hp_cat_nom
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape']

# %%
housePrice.groupby('LandContour')['SalePrice'].agg(['count','mean','std'])
hp_cat_nom.append('LandContour')
hp_cat_nom
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour']

# %%
housePrice.groupby('Utilities')['SalePrice'].agg(['count','mean','std'])
hp_cat_nom.append('Utilities')
hp_cat_nom
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities']

# %%
housePrice.groupby('LotConfig')['SalePrice'].agg(['count','mean','std'])
hp_cat_nom.append('LotConfig')
hp_cat_nom
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig']

# %%
housePrice.groupby('LandSlope')['SalePrice'].agg(['count','mean','std'])  # ordinal --> create scale map dict 
hp_cat_ord.append('LandSlope')
scale = {"Gtl":1, "Mod":2, "Sev":3}
housePrice['LandSlope_Enc'] = housePrice['LandSlope'].replace(scale)
housePrice = housePrice.drop(columns='LandSlope')
hp_cat_ord
# Out:
# ['LandSlope']

# %%
housePrice.groupby('Neighborhood')['SalePrice'].agg(['count','mean','std'])
hp_cat_nom.append('Neighborhood')
hp_cat_nom
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'Neighborhood']

# %%
housePrice.groupby('Condition1')['SalePrice'].agg(['count','mean','std'])
hp_cat_nom.append('Condition1')
hp_cat_nom
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'Neighborhood',
#  'Condition1']

# %%
housePrice.groupby('Condition2')['SalePrice'].agg(['count','mean','std'])
hp_cat_nom.append('Condition2')
hp_cat_nom
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'Neighborhood',
#  'Condition1',
#  'Condition2']

# %%
housePrice.groupby('BldgType')['SalePrice'].agg(['count','mean','std'])
hp_cat_nom.append('BldgType')
hp_cat_nom
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType']

# %%
housePrice.groupby('HouseStyle')['SalePrice'].agg(['count','mean','std'])
hp_cat_nom.append('HouseStyle')
hp_cat_nom
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle']

# %%
housePrice.groupby('RoofStyle')['SalePrice'].agg(['count','mean','std'])
hp_cat_nom.append('RoofStyle')
hp_cat_nom
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle']

# %%
housePrice.groupby('RoofMatl')['SalePrice'].agg(['count','mean','std'])
hp_cat_nom.append('RoofMatl')
hp_cat_nom
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl']

# %%
housePrice.groupby('Exterior1st')['SalePrice'].agg(['count','mean','std'])
hp_cat_nom.append('Exterior1st')
hp_cat_nom
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st']

# %%
housePrice.groupby('Exterior2nd')['SalePrice'].agg(['count','mean','std'])
hp_cat_nom.append('Exterior2nd')
hp_cat_nom
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd']

# %%
housePrice.groupby('MasVnrType')['SalePrice'].agg(['count','mean','std'])
hp_cat_nom.append('MasVnrType')
hp_cat_nom
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType']

# %%
housePrice.groupby('ExterQual')['SalePrice'].agg(['count','mean','std'])
hp_cat_ord.append('ExterQual')
scale = {"none":0, "TA":1, "Po": 2, "Fa":3, "Gd":4, "Ex":5}
housePrice['ExterQual_Enc'] = housePrice['ExterQual'].replace(scale)
housePrice = housePrice.drop(columns='ExterQual')
hp_cat_ord
# Out:
# ['LandSlope', 'ExterQual']

# %%
housePrice.groupby('ExterCond')['SalePrice'].agg(['count','mean','std'])
hp_cat_ord.append('ExterCond')
scale = {"none":0, "TA":1, "Po": 2, "Fa":3, "Gd":4, "Ex":5}
housePrice['ExterCond_Enc'] = housePrice['ExterCond'].replace(scale)
housePrice = housePrice.drop(columns='ExterCond')
hp_cat_ord
# Out:
# ['LandSlope', 'ExterQual', 'ExterCond']

# %%
housePrice.groupby('Foundation')['SalePrice'].agg(['count','mean','std'])
hp_cat_nom.append('Foundation')
hp_cat_nom
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'Foundation']

# %%
housePrice.groupby('BsmtQual')['SalePrice'].agg(['count','mean','std'])
hp_cat_ord.append('BsmtQual')
scale = {"none":0, "TA":1, "Po": 2, "Fa":3, "Gd":4, "Ex":5}
housePrice['BsmtQual_Enc'] = housePrice['BsmtQual'].replace(scale)
housePrice = housePrice.drop(columns='BsmtQual')
hp_cat_ord
# Out:
# ['LandSlope', 'ExterQual', 'ExterCond', 'BsmtQual']

# %%
housePrice.groupby('BsmtCond')['SalePrice'].agg(['count','mean','std'])
hp_cat_ord.append('BsmtCond')
scale = {"none":0, "TA":1, "Po": 2, "Fa":3, "Gd":4, "Ex":5}
housePrice['BsmtCond_Enc'] = housePrice['BsmtCond'].replace(scale)
housePrice = housePrice.drop(columns='BsmtCond')
hp_cat_ord
# Out:
# ['LandSlope', 'ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond']

# %%
housePrice.groupby('BsmtExposure')['SalePrice'].agg(['count','mean','std'])
hp_cat_ord.append('BsmtExposure')
scale = {"none":0, "No":1, "Mn": 2, "Av":3, "Gd":4, "Ex":5}
housePrice['BsmtExposure_Enc'] = housePrice['BsmtExposure'].replace(scale)
housePrice = housePrice.drop(columns='BsmtExposure')
len(hp_cat_ord)
# Out:
# 6

# %%
housePrice.groupby('BsmtFinType1')['SalePrice'].agg(['count','mean','std'])
hp_cat_ord.append('BsmtFinType1')
scale = {"none":0, "Unf":1, "LwQ": 2, "Rec":3, "BLQ":4, "ALQ":5, "GLQ":6}
housePrice['BsmtFinType1_Enc'] = housePrice['BsmtFinType1'].replace(scale)
housePrice = housePrice.drop(columns='BsmtFinType1')
len(hp_cat_ord)
# Out:
# 7

# %%
housePrice.groupby('BsmtFinType2')['SalePrice'].agg(['count','mean','std'])
hp_cat_ord.append('BsmtFinType2')
scale = {"none":0, "Unf":1, "LwQ": 2, "Rec":3, "BLQ":4, "ALQ":5, "GLQ":6}
housePrice['BsmtFinType2_Enc'] = housePrice['BsmtFinType2'].replace(scale)
housePrice = housePrice.drop(columns='BsmtFinType2')
hp_cat_ord
# Out:
# ['LandSlope',
#  'ExterQual',
#  'ExterCond',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2']

# %%
housePrice.groupby('Heating')['SalePrice'].agg(['count','mean','std'])
hp_cat_nom.append('Heating')
len(hp_cat_nom)
# Out:
# 19

# %%
housePrice.groupby('HeatingQC')['SalePrice'].agg(['count','mean','std'])
hp_cat_ord.append('HeatingQC')
scale = {"none":0, "TA":1, "Po": 2, "Fa":3, "Gd":4, "Ex":5}
housePrice['HeatingQC_Enc'] = housePrice['HeatingQC'].replace(scale)
housePrice = housePrice.drop(columns='HeatingQC')
hp_cat_ord
# Out:
# ['LandSlope',
#  'ExterQual',
#  'ExterCond',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'HeatingQC']

# %%
housePrice.groupby('CentralAir')['SalePrice'].agg(['count','mean','std'])
hp_cat_nom.append('CentralAir')
len(hp_cat_nom)
# Out:
# 20

# %%
housePrice.groupby('Electrical')['SalePrice'].agg(['count','mean','std'])
hp_cat_nom.append('Electrical')
len(hp_cat_nom)
# Out:
# 21

# %%
housePrice.groupby('KitchenQual')['SalePrice'].agg(['count','mean','std'])
hp_cat_ord.append('KitchenQual')
scale = {"none":0, "TA":1, "Po": 2, "Fa":3, "Gd":4, "Ex":5}
housePrice['KitchenQual_Enc'] = housePrice['KitchenQual'].replace(scale)
housePrice = housePrice.drop(columns='KitchenQual')
hp_cat_ord
# Out:
# ['LandSlope',
#  'ExterQual',
#  'ExterCond',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'HeatingQC',
#  'KitchenQual']

# %%
housePrice.groupby('Functional')['SalePrice'].agg(['count','mean','std'])
hp_cat_ord.append('Functional')
scale = {"Typ":0, "Min1":1, "Min2": 2, "Mod":3, "Maj1":4, "Maj2":5, "Sal":6}
housePrice['Functional_Enc'] = housePrice['Functional'].replace(scale)
housePrice = housePrice.drop(columns='Functional')
hp_cat_ord
# Out:
# ['LandSlope',
#  'ExterQual',
#  'ExterCond',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'HeatingQC',
#  'KitchenQual',
#  'Functional']

# %%
housePrice.groupby('FireplaceQu')['SalePrice'].agg(['count','mean','std'])
hp_cat_ord.append('FireplaceQu')
scale = {"none":0, "TA":1, "Po": 2, "Fa":3, "Gd":4, "Ex":5}
housePrice['FireplaceQu_Enc'] = housePrice['FireplaceQu'].replace(scale)
housePrice = housePrice.drop(columns='FireplaceQu')
hp_cat_ord
# Out:
# ['LandSlope',
#  'ExterQual',
#  'ExterCond',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'HeatingQC',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu']

# %%
housePrice.groupby('GarageType')['SalePrice'].agg(['count','mean','std'])
hp_cat_nom.append('GarageType')
len(hp_cat_nom)
# Out:
# 22

# %%
housePrice.groupby('GarageFinish')['SalePrice'].agg(['count','mean','std'])
hp_cat_ord.append('GarageFinish')
scale = {"none":0, "Unf":1, "RFn": 2, "Fin":3}
housePrice['GarageFinish_Enc'] = housePrice['GarageFinish'].replace(scale)
housePrice = housePrice.drop(columns='GarageFinish')
len(hp_cat_ord)
# Out:
# 13

# %%
housePrice.groupby('GarageQual')['SalePrice'].agg(['count','mean','std'])
hp_cat_ord.append('GarageQual')
scale = {"none":0, "TA":1, "Po": 2, "Fa":3, "Gd":4, "Ex":5}
housePrice['GarageQual_Enc'] = housePrice['GarageQual'].replace(scale)
housePrice = housePrice.drop(columns='GarageQual')
len(hp_cat_ord)
# Out:
# 14

# %%
housePrice.groupby('GarageCond')['SalePrice'].agg(['count','mean','std'])
hp_cat_ord.append('GarageCond')
scale = {"none":0, "TA":1, "Po": 2, "Fa":3, "Gd":4, "Ex":5}
housePrice['GarageCond_Enc'] = housePrice['GarageCond'].replace(scale)
housePrice = housePrice.drop(columns='GarageCond')
len(hp_cat_ord)
# Out:
# 15

# %%
housePrice.groupby('PavedDrive')['SalePrice'].agg(['count','mean','std'])
hp_cat_ord.append('PavedDrive')
scale = {"N":0, "P":1, "Y": 2}
housePrice['PavedDrive_Enc'] = housePrice['PavedDrive'].replace(scale)
housePrice = housePrice.drop(columns='PavedDrive')
len(hp_cat_ord)
# Out:
# 16

# %%
housePrice.groupby('PoolQC')['SalePrice'].agg(['count','mean','std'])
hp_cat_ord.append('PoolQC')
scale = {"none":0, "TA":1, "Po": 2, "Fa":3, "Gd":4, "Ex":5}
housePrice['PoolQC_Enc'] = housePrice['PoolQC'].replace(scale)
housePrice = housePrice.drop(columns='PoolQC')
len(hp_cat_ord)
# Out:
# 17

# %%
housePrice.groupby('Fence')['SalePrice'].agg(['count','mean','std'])   ### measuring two completely different things
dropped.append('Fence')
housePrice = housePrice.drop(columns='Fence')                                           ## DROP

# %%
housePrice.groupby('SaleType')['SalePrice'].agg(['count','mean','std'])
hp_cat_nom.append('SaleType')
len(hp_cat_nom)
# Out:
# 23

# %%
housePrice.groupby('SaleCondition')['SalePrice'].agg(['count','mean','std'])
hp_cat_nom.append('SaleCondition')
len(hp_cat_nom)
# Out:
# 24

# %%
# see if ordinal/nominal add up
print("ordinal", len(hp_cat_ord))
print("nominal", len(hp_cat_nom))
print("categorical total", hp_cat.shape[1])
# Out:
# ordinal 17
# nominal 24
# categorical total 42

# %%
hp_cat.columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'SaleType',
#        'SaleCondition'],
#       dtype='object')

# %% [markdown]
# ## Correlation (before OneHot Encoding)

# %% [markdown]
# ### Assessing for Multicollinearity

# %%
corr=housePrice.corr()
plt.figure(figsize = (16, 16))
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values, cmap ="Blues")
plt.title('Heatmap of Correlation Matrix')
corr
# Out:
#                   GrLivArea  SalePrice  MSSubClass   LotArea  OverallQual  \
# GrLivArea          1.000000   0.719981    0.070785  0.260322     0.559897
# SalePrice          0.719981   1.000000   -0.084587  0.274443     0.790501
# MSSubClass         0.070785  -0.084587    1.000000 -0.198040     0.056468
# LotArea            0.260322   0.274443   -0.198040  1.000000     0.080607
# OverallQual        0.559897   0.790501    0.056468  0.080607     1.000000
# OverallCond       -0.105670  -0.101091   -0.075542 -0.032693    -0.095927
# YearBuilt          0.228400   0.544370    0.053852  0.012397     0.574400
# YearRemodAdd       0.306035   0.514309    0.056756  0.010293     0.546297
# MasVnrArea         0.385898   0.498432    0.018243  0.103514     0.401996
# BsmtFinSF1         0.164852   0.460636   -0.074081  0.163460     0.273800
# BsmtFinSF2        -0.021051   0.022512   -0.074080  0.082335    -0.030370
# BsmtUnfSF          0.245476   0.167463   -0.113240  0.019737     0.255587
# TotalBsmtSF        0.409698   0.652002   -0.221898  0.222031     0.527840
# 1stFlrSF           0.539135   0.642613   -0.255798  0.313086     0.454481
# 2ndFlrSF           0.665001   0.263144    0.306929  0.022434     0.246885
# LowQualFinSF       0.088931  -0.030835    0.013473 -0.000334    -0.044359
# BsmtFullBath      -0.053499  -0.033786   -0.010403  0.027077    -0.050320
# BsmtHalfBath      -0.053499  -0.033786   -0.010403  0.027077    -0.050320
# FullBath           0.643937   0.534982    0.144475  0.124352     0.508255
# HalfBath           0.445513   0.285875    0.181780  0.026727     0.271455
# BedroomAbvGr       0.538022   0.151806   -0.023680  0.140430     0.067466
# KitchenAbvGr       0.129797  -0.113977    0.251357 -0.014575    -0.153691
# TotRmsAbvGrd       0.807445   0.490219    0.032047  0.204545     0.360675
# Fireplaces         0.457926   0.488184   -0.047790  0.245148     0.387777
# GarageYrBlt        0.148891   0.245699   -0.094049  0.068698     0.267269
# GarageCars         0.495045   0.638722   -0.031923  0.175712     0.580843
# GarageArea         0.477116   0.634971   -0.091172  0.199239     0.538111
# WoodDeckSF         0.247716   0.333232   -0.017656  0.155687     0.250181
# OpenPorchSF        0.321777   0.306540   -0.007649  0.084963     0.286861
# EnclosedPorch      0.000196  -0.123235   -0.028535  0.017694    -0.134291
# 3SsnPorch          0.008714   0.031260   -0.041798  0.017721     0.014226
# ScreenPorch        0.097835   0.121463   -0.055099  0.053820     0.049277
# PoolArea           0.057935   0.030844   -0.013431  0.052636    -0.002484
# MiscVal           -0.003940  -0.018877   -0.027226  0.040220    -0.025825
# MoSold             0.038389   0.012591    0.007252  0.010203     0.016780
# YrSold            -0.008260  -0.001376   -0.025351 -0.017319     0.005668
# LandSlope_Enc      0.033891   0.078882   -0.036835  0.357976    -0.017671
# ExterQual_Enc      0.397747   0.626728    0.059235  0.025981     0.666686
# ExterCond_Enc     -0.030240  -0.089642   -0.029761  0.002337    -0.140543
# BsmtQual_Enc       0.340806   0.581255    0.133259  0.045624     0.615916
# BsmtCond_Enc       0.026217   0.025935   -0.012948  0.000534     0.033562
# BsmtExposure_Enc   0.122396   0.409257    0.068790  0.180604     0.340721
# BsmtFinType1_Enc   0.058851   0.352771    0.059895  0.031506     0.293822
# BsmtFinType2_Enc  -0.037962   0.025494   -0.035436  0.055343    -0.001032
# HeatingQC_Enc      0.262223   0.396706   -0.014753  0.001002     0.397544
# KitchenQual_Enc    0.384736   0.588980   -0.005057  0.044683     0.596783
# Functional_Enc     0.077225  -0.103462    0.012495  0.077334    -0.170620
# FireplaceQu_Enc    0.365403   0.458405   -0.067130  0.147225     0.399744
# GarageFinish_Enc   0.348129   0.533627   -0.018207  0.107698     0.524713
# GarageQual_Enc     0.027058   0.008012   -0.062426  0.015401    -0.005057
# GarageCond_Enc     0.015629  -0.012181   -0.058419  0.013619    -0.020462
# PavedDrive_Enc     0.125275   0.268327   -0.017050 -0.007465     0.288091
# PoolQC_Enc         0.074332   0.087288   -0.017598  0.032242     0.043693
#
#                   OverallCond  YearBuilt  YearRemodAdd  MasVnrArea  \
# GrLivArea           -0.105670   0.228400      0.306035    0.385898
# SalePrice           -0.101091   0.544370      0.514309    0.498432
# MSSubClass          -0.075542   0.053852      0.056756    0.018243
# LotArea             -0.032693   0.012397      0.010293    0.103514
# OverallQual         -0.095927   0.574400      0.546297    0.401996
# OverallCond          1.000000  -0.397274      0.065100   -0.142250
# YearBuilt           -0.397274   1.000000      0.572276    0.302447
# YearRemodAdd         0.065100   0.572276      1.000000    0.171725
# MasVnrArea          -0.142250   0.302447      0.171725    1.000000
# BsmtFinSF1          -0.064328   0.303577      0.156444    0.275866
# BsmtFinSF2           0.029981  -0.009806     -0.051175   -0.008940
# BsmtUnfSF           -0.123962   0.092159      0.130580    0.080097
# TotalBsmtSF         -0.179420   0.400931      0.271800    0.360614
# 1stFlrSF            -0.156592   0.294691      0.217709    0.361919
# 2ndFlrSF             0.015073   0.015754      0.166301    0.129439
# LowQualFinSF         0.019018  -0.132086     -0.063714   -0.053804
# BsmtFullBath         0.084865  -0.028676     -0.048489    0.003325
# BsmtHalfBath         0.084865  -0.028676     -0.048489    0.003325
# FullBath            -0.210226   0.450065      0.434877    0.253571
# HalfBath            -0.096052   0.272979      0.209656    0.197442
# BedroomAbvGr         0.004108  -0.048768     -0.016713    0.104035
# KitchenAbvGr        -0.075642  -0.136983     -0.145110   -0.039454
# TotRmsAbvGrd        -0.072482   0.095450      0.185204    0.261412
# Fireplaces          -0.046570   0.167188      0.123843    0.246354
# GarageYrBlt         -0.013266   0.247856      0.133711    0.122385
# GarageCars          -0.195726   0.519016      0.398161    0.345994
# GarageArea          -0.168230   0.462926      0.348419    0.347296
# WoodDeckSF           0.014161   0.227289      0.218273    0.149983
# OpenPorchSF         -0.067437   0.179654      0.226677    0.119097
# EnclosedPorch        0.085910  -0.360933     -0.205205   -0.102313
# 3SsnPorch            0.041904   0.009513      0.028543    0.011964
# ScreenPorch          0.050417  -0.042655     -0.043130    0.064982
# PoolArea            -0.021193   0.004925     -0.018693   -0.003637
# MiscVal              0.046015  -0.027354     -0.016669   -0.021630
# MoSold               0.012211  -0.007534      0.002476   -0.007766
# YrSold               0.017632   0.015349      0.064046   -0.020050
# LandSlope_Enc       -0.003553  -0.028644     -0.033191    0.008834
# ExterQual_Enc       -0.196883   0.568561      0.565706    0.291601
# ExterCond_Enc        0.324707  -0.253389     -0.011985   -0.055382
# BsmtQual_Enc        -0.273163   0.681853      0.561378    0.245242
# BsmtCond_Enc         0.051424  -0.064805      0.022386   -0.029413
# BsmtExposure_Enc    -0.079135   0.310179      0.226661    0.200985
# BsmtFinType1_Enc    -0.029482   0.409093      0.263198    0.204198
# BsmtFinType2_Enc     0.081021   0.005035     -0.013389   -0.006113
# HeatingQC_Enc       -0.022693   0.353059      0.480558    0.138530
# KitchenQual_Enc     -0.063993   0.475910      0.591742    0.243105
# Functional_Enc      -0.106980  -0.160484     -0.079975   -0.076441
# FireplaceQu_Enc     -0.045408   0.151080      0.164248    0.228658
# GarageFinish_Enc    -0.195723   0.579106      0.414106    0.257828
# GarageQual_Enc       0.080899  -0.166146     -0.068760   -0.035162
# GarageCond_Enc      -0.008236  -0.086983     -0.066300   -0.005532
# PavedDrive_Enc      -0.052298   0.464789      0.191084    0.159312
# PoolQC_Enc          -0.021996   0.019385      0.000825    0.023931
#
#                   BsmtFinSF1  ...  BsmtFinType2_Enc  HeatingQC_Enc  \
# GrLivArea           0.164852  ...         -0.037962       0.262223
# SalePrice           0.460636  ...          0.025494       0.396706
# MSSubClass         -0.074081  ...         -0.035436      -0.014753
# LotArea             0.163460  ...          0.055343       0.001002
# OverallQual         0.273800  ...         -0.001032       0.397544
# OverallCond        -0.064328  ...          0.081021      -0.022693
# YearBuilt           0.303577  ...          0.005035       0.353059
# YearRemodAdd        0.156444  ...         -0.013389       0.480558
# MasVnrArea          0.275866  ...         -0.006113       0.138530
# BsmtFinSF1          1.000000  ...         -0.010687       0.070259
# BsmtFinSF2         -0.058911  ...          0.801976      -0.073301
# BsmtUnfSF          -0.480927  ...         -0.195990       0.156220
# TotalBsmtSF         0.512642  ...          0.124142       0.200221
# 1stFlrSF            0.426727  ...          0.043057       0.147361
# 2ndFlrSF           -0.180945  ...         -0.081419       0.174956
# LowQualFinSF       -0.070774  ...         -0.004737      -0.032892
# BsmtFullBath        0.067500  ...          0.101003      -0.055521
# BsmtHalfBath        0.067500  ...          0.101003      -0.055521
# FullBath            0.084501  ...         -0.080393       0.297768
# HalfBath           -0.023824  ...         -0.032936       0.168078
# BedroomAbvGr       -0.106482  ...         -0.056321      -0.004632
# KitchenAbvGr       -0.105859  ...         -0.085189      -0.136021
# TotRmsAbvGrd        0.016546  ...         -0.074879       0.170181
# Fireplaces          0.278625  ...          0.050354       0.116636
# GarageYrBlt         0.125758  ...          0.053141       0.084981
# GarageCars          0.261737  ...         -0.011229       0.289079
# GarageArea          0.298262  ...          0.012584       0.247862
# WoodDeckSF          0.217399  ...          0.102311       0.098262
# OpenPorchSF         0.100375  ...         -0.014480       0.186542
# EnclosedPorch      -0.107393  ...          0.008123      -0.082858
# 3SsnPorch           0.044348  ...          0.003391       0.031827
# ScreenPorch         0.102108  ...          0.029115      -0.022919
# PoolArea            0.017784  ...          0.031697      -0.007049
# MiscVal             0.014571  ...          0.001199      -0.023876
# MoSold             -0.003877  ...          0.007996      -0.009801
# YrSold              0.014207  ...          0.021689       0.002831
# LandSlope_Enc       0.115214  ...          0.084210      -0.016945
# ExterQual_Enc       0.187827  ...         -0.020676       0.467161
# ExterCond_Enc      -0.037135  ...          0.071588       0.006533
# BsmtQual_Enc        0.271001  ...          0.007195       0.395165
# BsmtCond_Enc        0.006634  ...          0.111261       0.012708
# BsmtExposure_Enc    0.408991  ...          0.143420       0.107790
# BsmtFinType1_Enc    0.715119  ...          0.093043       0.125659
# BsmtFinType2_Enc   -0.010687  ...          1.000000      -0.047988
# HeatingQC_Enc       0.070259  ...         -0.047988       1.000000
# KitchenQual_Enc     0.181450  ...         -0.023959       0.461866
# Functional_Enc     -0.066697  ...          0.017134      -0.044993
# FireplaceQu_Enc     0.176789  ...         -0.020608       0.162697
# GarageFinish_Enc    0.271445  ...          0.019882       0.308096
# GarageQual_Enc     -0.047864  ...         -0.012418      -0.015292
# GarageCond_Enc     -0.024062  ...          0.014888       0.001297
# PavedDrive_Enc      0.226451  ...          0.092255       0.109156
# PoolQC_Enc          0.047171  ...          0.021402      -0.006156
#
#                   KitchenQual_Enc  Functional_Enc  FireplaceQu_Enc  \
# GrLivArea                0.384736        0.077225         0.365403
# SalePrice                0.588980       -0.103462         0.458405
# MSSubClass              -0.005057        0.012495        -0.067130
# LotArea                  0.044683        0.077334         0.147225
# OverallQual              0.596783       -0.170620         0.399744
# OverallCond             -0.063993       -0.106980        -0.045408
# YearBuilt                0.475910       -0.160484         0.151080
# YearRemodAdd             0.591742       -0.079975         0.164248
# MasVnrArea               0.243105       -0.076441         0.228658
# BsmtFinSF1               0.181450       -0.066697         0.176789
# BsmtFinSF2              -0.041384        0.054396        -0.008298
# BsmtUnfSF                0.184538       -0.034890         0.139882
# TotalBsmtSF              0.356345       -0.081191         0.319986
# 1stFlrSF                 0.319523        0.073110         0.372001
# 2ndFlrSF                 0.163085        0.012977         0.091194
# LowQualFinSF            -0.028964        0.106888         0.000550
# BsmtFullBath            -0.067496       -0.006679        -0.008674
# BsmtHalfBath            -0.067496       -0.006679        -0.008674
# FullBath                 0.403190       -0.003578         0.207755
# HalfBath                 0.184068       -0.047014         0.092813
# BedroomAbvGr            -0.027520        0.022595         0.040321
# KitchenAbvGr            -0.156190        0.014895        -0.117737
# TotRmsAbvGrd             0.213556        0.057050         0.266164
# Fireplaces               0.195470        0.035194         0.699090
# GarageYrBlt              0.126640       -0.055378         0.150268
# GarageCars               0.406924       -0.059812         0.302197
# GarageArea               0.385683       -0.049244         0.278874
# WoodDeckSF               0.199400       -0.002010         0.161348
# OpenPorchSF              0.229319        0.006524         0.132821
# EnclosedPorch           -0.114900        0.080890        -0.030562
# 3SsnPorch                0.003291        0.015005         0.035842
# ScreenPorch              0.006359        0.022057         0.108704
# PoolArea                 0.018653        0.071331         0.015489
# MiscVal                 -0.026094        0.019343        -0.030148
# MoSold                   0.034113       -0.000230         0.025746
# YrSold                   0.036114       -0.001703        -0.007390
# LandSlope_Enc           -0.000925        0.075176         0.037471
# ExterQual_Enc            0.694116       -0.059409         0.278037
# ExterCond_Enc           -0.049813        0.027356        -0.058465
# BsmtQual_Enc             0.518313       -0.114473         0.200238
# BsmtCond_Enc             0.015822       -0.001334         0.036176
# BsmtExposure_Enc         0.227357       -0.073679         0.189718
# BsmtFinType1_Enc         0.230869       -0.136389         0.082849
# BsmtFinType2_Enc        -0.023959        0.017134        -0.020608
# HeatingQC_Enc            0.461866       -0.044993         0.162697
# KitchenQual_Enc          1.000000       -0.080433         0.269455
# Functional_Enc          -0.080433        1.000000        -0.015087
# FireplaceQu_Enc          0.269455       -0.015087         1.000000
# GarageFinish_Enc         0.380801       -0.110726         0.281394
# GarageQual_Enc          -0.010714        0.015570         0.040235
# GarageCond_Enc          -0.013445        0.041327         0.031725
# PavedDrive_Enc           0.115696       -0.138879         0.102980
# PoolQC_Enc               0.035994        0.036095         0.037020
#
#                   GarageFinish_Enc  GarageQual_Enc  GarageCond_Enc  \
# GrLivArea                 0.348129        0.027058        0.015629
# SalePrice                 0.533627        0.008012       -0.012181
# MSSubClass               -0.018207       -0.062426       -0.058419
# LotArea                   0.107698        0.015401        0.013619
# OverallQual               0.524713       -0.005057       -0.020462
# OverallCond              -0.195723        0.080899       -0.008236
# YearBuilt                 0.579106       -0.166146       -0.086983
# YearRemodAdd              0.414106       -0.068760       -0.066300
# MasVnrArea                0.257828       -0.035162       -0.005532
# BsmtFinSF1                0.271445       -0.047864       -0.024062
# BsmtFinSF2                0.014722       -0.023161        0.011403
# BsmtUnfSF                 0.050002        0.024213       -0.005862
# TotalBsmtSF               0.335367       -0.034151       -0.025884
# 1stFlrSF                  0.316700       -0.011883       -0.013820
# 2ndFlrSF                  0.127821        0.037925        0.029236
# LowQualFinSF             -0.071133        0.036172        0.009793
# BsmtFullBath             -0.024220       -0.027583       -0.021210
# BsmtHalfBath             -0.024220       -0.027583       -0.021210
# FullBath                  0.377412       -0.058764       -0.033783
# HalfBath                  0.237449       -0.011723       -0.008975
# BedroomAbvGr             -0.005341       -0.048945       -0.029337
# KitchenAbvGr             -0.169979       -0.051230       -0.019462
# TotRmsAbvGrd              0.210308       -0.000446        0.006335
# Fireplaces                0.312261        0.029342        0.013489
# GarageYrBlt               0.466977        0.422730        0.485084
# GarageCars                0.550131        0.129161        0.188921
# GarageArea                0.487372        0.138139        0.180805
# WoodDeckSF                0.253253       -0.011363       -0.005970
# OpenPorchSF               0.191943       -0.006963       -0.019306
# EnclosedPorch            -0.188226        0.083202        0.034497
# 3SsnPorch                 0.015440        0.023002        0.000459
# ScreenPorch               0.056778        0.069127        0.008603
# PoolArea                  0.030482        0.009056        0.015297
# MiscVal                  -0.007993       -0.016525       -0.014382
# MoSold                   -0.021768        0.003611        0.027076
# YrSold                    0.006305       -0.040153       -0.026593
# LandSlope_Enc             0.002131       -0.002985        0.004475
# ExterQual_Enc             0.452838       -0.021428       -0.025403
# ExterCond_Enc            -0.141672        0.029587       -0.014857
# BsmtQual_Enc              0.497651       -0.052642       -0.029759
# BsmtCond_Enc             -0.031629        0.057835        0.061313
# BsmtExposure_Enc          0.269193       -0.044753       -0.025656
# BsmtFinType1_Enc          0.276620       -0.080764       -0.050422
# BsmtFinType2_Enc          0.019882       -0.012418        0.014888
# HeatingQC_Enc             0.308096       -0.015292        0.001297
# KitchenQual_Enc           0.380801       -0.010714       -0.013445
# Functional_Enc           -0.110726        0.015570        0.041327
# FireplaceQu_Enc           0.281394        0.040235        0.031725
# GarageFinish_Enc          1.000000        0.068885        0.132943
# GarageQual_Enc            0.068885        1.000000        0.541084
# GarageCond_Enc            0.132943        0.541084        1.000000
# PavedDrive_Enc            0.306312       -0.060517       -0.066903
# PoolQC_Enc                0.047806        0.045800        0.058448
#
#                   PavedDrive_Enc  PoolQC_Enc
# GrLivArea               0.125275    0.074332
# SalePrice               0.268327    0.087288
# MSSubClass             -0.017050   -0.017598
# LotArea                -0.007465    0.032242
# OverallQual             0.288091    0.043693
# OverallCond            -0.052298   -0.021996
# YearBuilt               0.464789    0.019385
# YearRemodAdd            0.191084    0.000825
# MasVnrArea              0.159312    0.023931
# BsmtFinSF1              0.226451    0.047171
# BsmtFinSF2              0.074240    0.038354
# BsmtUnfSF              -0.022098   -0.031548
# TotalBsmtSF             0.240773    0.032321
# 1stFlrSF                0.187371    0.108684
# 2ndFlrSF               -0.020870   -0.010176
# LowQualFinSF           -0.008504   -0.005015
# BsmtFullBath            0.040520    0.050282
# BsmtHalfBath            0.040520    0.050282
# FullBath                0.144343    0.004019
# HalfBath                0.134636    0.022518
# BedroomAbvGr            0.044407   -0.011712
# KitchenAbvGr           -0.121846   -0.010440
# TotRmsAbvGrd            0.055128    0.032330
# Fireplaces              0.160813    0.088922
# GarageYrBlt             0.309506    0.012538
# GarageCars              0.268350    0.023184
# GarageArea              0.271008    0.031913
# WoodDeckSF              0.122566    0.062316
# OpenPorchSF             0.048992    0.017579
# EnclosedPorch          -0.212835    0.037284
# 3SsnPorch               0.007830   -0.005208
# ScreenPorch             0.044011    0.067103
# PoolArea               -0.020601    0.780837
# MiscVal                -0.013260    0.018249
# MoSold                  0.007539   -0.034972
# YrSold                  0.010490   -0.034993
# LandSlope_Enc           0.007170    0.028528
# ExterQual_Enc           0.140745    0.022194
# ExterCond_Enc          -0.108510   -0.004734
# BsmtQual_Enc            0.223272    0.014978
# BsmtCond_Enc           -0.057950   -0.014845
# BsmtExposure_Enc        0.147234    0.032427
# BsmtFinType1_Enc        0.288036    0.009126
# BsmtFinType2_Enc        0.092255    0.021402
# HeatingQC_Enc           0.109156   -0.006156
# KitchenQual_Enc         0.115696    0.035994
# Functional_Enc         -0.138879    0.036095
# FireplaceQu_Enc         0.102980    0.037020
# GarageFinish_Enc        0.306312    0.047806
# GarageQual_Enc         -0.060517    0.045800
# GarageCond_Enc         -0.066903    0.058448
# PavedDrive_Enc          1.000000    0.005420
# PoolQC_Enc              0.005420    1.000000
#
# [53 rows x 53 columns]

# %%
high_corr_pairs = np.where(abs(corr) > 0.7)
high_corr_pairs = [(corr.index[x], corr.columns[y]) 
                   for x, y in  zip(*high_corr_pairs)
                   if x != y and x < y]

# %%
high_corr_pairs
# Out:
# [('GrLivArea', 'SalePrice'),
#  ('GrLivArea', 'TotRmsAbvGrd'),
#  ('SalePrice', 'OverallQual'),
#  ('BsmtFinSF1', 'BsmtFinType1_Enc'),
#  ('BsmtFinSF2', 'BsmtFinType2_Enc'),
#  ('TotalBsmtSF', '1stFlrSF'),
#  ('BsmtFullBath', 'BsmtHalfBath'),
#  ('GarageCars', 'GarageArea'),
#  ('PoolArea', 'PoolQC_Enc')]

# %% [markdown]
# ### High Correlation with SalePrice

# %%
top_corr_features = housePrice.corrwith(housePrice['SalePrice']).sort_values(ascending=False)
top_corr_features.where(top_corr_features > .6, inplace=True)
top_corr_features.dropna(inplace=True)
top_corr_features
# Out:
# SalePrice        1.000000
# OverallQual      0.790501
# GrLivArea        0.719981
# TotalBsmtSF      0.652002
# 1stFlrSF         0.642613
# GarageCars       0.638722
# GarageArea       0.634971
# ExterQual_Enc    0.626728
# dtype: float64

# %%
for feature in top_corr_features.index:
    if feature == 'SalePrice':
        continue
    feature_plot(housePrice, feature)
# Out:
# C:\Users\hzeig\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hzeig\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hzeig\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hzeig\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hzeig\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hzeig\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hzeig\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## OneHot Encoding for nominals

# %%
hp_num = housePrice.select_dtypes(include = [np.number])
hp_cat = housePrice.select_dtypes(exclude = [np.number])
print("numberfied:", hp_num.shape[1])
print("to OneHot:", hp_cat.shape[1])
# Out:
# numberfied: 53
# to OneHot: 24

# %%
housePrice = pd.get_dummies(housePrice, columns=hp_cat_nom, drop_first=True)

# %%
housePrice.to_csv('HousePrice_Encoded.csv', index = False)
